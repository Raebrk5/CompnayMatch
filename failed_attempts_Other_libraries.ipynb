# %%
import pandas as pd
import re
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
import codecs

#Having trouble with the formatting over to .csv because of ,.\| ect in company names (but they can't be elimited)
#tsv = open("usDcaDailyRun_2018_03_08.tsv", 'r')
#fileContent =  tsv.read()
#fileContent = re.sub("\t", ",", fileContent) # convert from tab to comma
#csv_file = open("Daily.csv", "w")
#csv_file.write(fileContent)
#csv_file.close()
#Calls in the .tsv, sets headers row, creates daily_list (set to the comapany name ONLY) & sets all values to lower case

companies = {
    'acura': 'AUTO',
'audi': 'AUTO',
'bentley': 'AUTO',
'benz': 'AUTO',
'bmw': 'AUTO',
'buick': 'AUTO',
'cadillac': 'AUTO',
'chevrolet': 'AUTO',
'chevy': 'AUTO',
'chrysler': 'AUTO',
'dodge': 'AUTO',
'ferrari': 'AUTO',
'fiat': 'AUTO',
'ford': 'AUTO',
'gmc': 'AUTO',
'harley davidson': 'AUTO',
'honda': 'AUTO',
'hyundai': 'AUTO',
'infiniti': 'AUTO',
'jaguar': 'AUTO',
'jeep': 'AUTO',
'kia': 'AUTO',
'land rover': 'AUTO',
'lexus': 'AUTO',
'maserati': 'AUTO',
'mazda': 'AUTO',
'mercedes': 'AUTO',
'mercury': 'AUTO',
'mini': 'AUTO',
'mitsubishi': 'AUTO',
'nissan': 'AUTO',
'porsche': 'AUTO',
'powersport': 'AUTO',
'powersports': 'AUTO',
'saturn': 'AUTO',
'subaru': 'AUTO',
'suzuki': 'AUTO',
'toyota': 'AUTO',
'volkswagen': 'AUTO',
'volvo': 'AUTO',
'yamaha': 'AUTO',
'1-800-got-junk': 'COMM',
'360clean': 'COMM',
'aamco': 'COMM',
'aaron%s': 'COMM',
'ace hardware': 'COMM',
'american homeshield': 'COMM',
'american leak detection': 'COMM',
'amerispec': 'COMM',
'anago cleaning systems': 'COMM',
'ashley furniture': 'COMM',
'ashley homestore': 'COMM',
'at&t wireless retailers': 'COMM',
'automotive dealerships nationwide': 'COMM',
'big o tires': 'COMM',
'boost mobile': 'COMM',
'budget blinds inc.': 'COMM',
'buildingstars int': 'COMM',
'certa pro': 'COMM',
'chem-dry': 'COMM',
'christian brothers': 'COMM',
'cleannet usa': 'COMM',
'college hunks': 'COMM',
'coverall north america, inc.': 'COMM',
'cricket wireless': 'COMM',
'edible arrangements': 'COMM',
'european wax': 'COMM',
'express oil change': 'COMM',
'fast signs': 'COMM',
'furniture medic': 'COMM',
'game truck': 'COMM',
'gnc': 'COMM',
'grease monkey intl': 'COMM',
'honest-1': 'COMM',
'hoodz': 'COMM',
'jan-pro': 'COMM',
'jantize america': 'COMM',
'jiffy lube int%l. inc.': 'COMM',
'la-z-boy': 'COMM',
'lawn doctor': 'COMM',
'les schwab': 'COMM',
'maaco': 'COMM',
'maid brigade': 'COMM',
'maidpro, inc.': 'COMM',
'matco inc': 'COMM',
'meineke car care centers': 'COMM',
'merry maids': 'COMM',
'metro & pcs': 'COMM',
'midas': 'COMM',
'minuteman press': 'COMM',
'miracle-ear, inc.': 'COMM',
'molly maid': 'COMM',
'mosquito authority': 'COMM',
'mosquito joe': 'COMM',
'mr. appliance': 'COMM',
'mr. electric': 'COMM',
'mr. rooter plumbing': 'COMM',
'office pride commercial cleaning': 'COMM',
'oil can henry%s': 'COMM',
'openworks': 'COMM',
'painting with a twist': 'COMM',
'pandora jewelry': 'COMM',
'payless shoesource': 'COMM',
'plato%s closet': 'COMM',
'platocloset': 'COMM',
'postal annex': 'COMM',
'precision door': 'COMM',
'precision tune auto care': 'COMM',
'rainbow international': 'COMM',
'rooter man corp': 'COMM',
'roto-rooter': 'COMM',
'servicemaster': 'COMM',
'servpro': 'COMM',
'seven eleven': 'COMM',
'signarama': 'COMM',
'snap-on tool': 'COMM',
'sprint': 'COMM',
'stanley steamer': 'COMM',
'superglass': 'COMM',
'system4': 'COMM',
't-mobile': 'COMM',
'terminix': 'COMM',
'the cleaning authority': 'COMM',
'the maids': 'COMM',
'tmobile': 'COMM',
'travel leaders': 'COMM',
'two maids & a mop': 'COMM',
'u.s. cellular ': 'COMM',
'ups': 'COMM',
'ups store': 'COMM',
'us cellular': 'COMM',
'valvoline': 'COMM',
'valvoline instant oil change': 'COMM',
'vanguard cleaning': 'COMM',
'verizon ': 'COMM',
'virgin mobile': 'COMM',
'weed man': 'COMM',
'wild birds unlimited': 'COMM',
'window genie': 'COMM',
'wizehire': 'COMM',
'you%ve got maids': 'COMM',
'aflac': 'INS',
'allied insurance': 'INS',
'allstate': 'INS',
'ameriprise': 'INS',
'axa advisors': 'INS',
'better homes and gardens': 'INS',
'century 21': 'INS',
'coldwell banker': 'INS',
'colonial life accident insurance': 'INS',
'colonial life': 'INS',
'conrad': 'INS',
'edward jones': 'INS',
'era franchise systems llc': 'INS',
'erie insurance': 'INS',
'farm bureau property & casualty insurance co.': 'INS',
'farmers insurance': 'INS',
'guardian life': 'INS',
'insurance': 'INS',
'jackson hewitt': 'INS',
'keller williams': 'INS',
'kemper': 'INS',
'liberty mutual': 'INS',
'liberty national': 'INS',
'liberty tax': 'INS',
'marcus & millichap': 'INS',
'massmutual': 'INS',
'metlife': 'INS',
'nationwide mutual insurance company': 'INS',
'new york life': 'INS',
'northwestern mutual': 'INS',
'ny life': 'INS',
'progressive': 'INS',
'prudential financial': 'INS',
'raymond james ': 'INS',
're/max llc': 'INS',
'realogy': 'INS',
'realty executives': 'INS',
'state farm automobile insurance company': 'INS',
'travelers insurance': 'INS',
'progressive': 'INS',
'unum group': 'INS',
'we insure': 'INS',
'weichert': 'INS',
'weinsure': 'INS',
'western southern': 'INS',
'7 eleven': 'QSR',
'applebee%s': 'QSR',
'auntie anne%s': 'QSR',
'blaze pizza': 'QSR',
'bojangles': 'QSR',
'buffalo wild wings': 'QSR',
'burger king': 'QSR',
'bww': 'QSR',
'california tortilla': 'QSR',
'carl%s jr': 'QSR',
'charley%s philly steaks': 'QSR',
'checkers hamburgers': 'QSR',
'chester%s international, llc': 'QSR',
'chick-fil-a': 'QSR',
'churchs chicken': 'QSR',
'cici%s pizza': 'QSR',
'cinnabon': 'QSR',
'circle k': 'QSR',
'club z': 'QSR',
'cold stone creamery': 'QSR',
'culver%s': 'QSR',
'dairy queen': 'QSR',
'del taco holdings': 'QSR',
'dennys': 'QSR',
'dickey%s bbq': 'QSR',
'domino%s': 'QSR',
'dunkin donughts': 'QSR',
'firehouse subs': 'QSR',
'five guys': 'QSR',
'golden corral': 'QSR',
'great american cookies company': 'QSR',
'hardee%s': 'QSR',
'hooters': 'QSR',
'hungry howies pizza': 'QSR',
'ihop': 'QSR',
'jack in the box': 'QSR',
'jamba juice': 'QSR',
'jersey mikes': 'QSR',
'jet%s pizza': 'QSR',
'jimmy john%s': 'QSR',
'johnny rockets': 'QSR',
'kentucky fried': 'QSR',
'krispy kreme': 'QSR',
'little caesar%s pizza': 'QSR',
'louisiana kitchen': 'QSR',
'marco%s pizza': 'QSR',
'mcalister%s deli': 'QSR',
'mcdonald%s': 'QSR',
'mellow mushroom': 'QSR',
'moe%s southwest grill': 'QSR',
'mooyah': 'QSR',
'noble roman%s, inc.': 'QSR',
'nothing bundt cake': 'QSR',
'papa john%s': 'QSR',
'papa murphy': 'QSR',
'penn station east coast subs': 'QSR',
'pizza hut': 'QSR',
'popeyes': 'QSR',
'popeyes louisiana kitchen': 'QSR',
'potbelly': 'QSR',
'potbelly sandwich shop': 'QSR',
'rallys hamburgers': 'QSR',
'red robin': 'QSR',
'round table pizza, inc.': 'QSR',
'ruby tuesday': 'QSR',
'schlotzky%s': 'QSR',
'smoothie king': 'QSR',
'steak %n% shake': 'QSR',
'subway': 'QSR',
'taco bell': 'QSR',
'taco john%s': 'QSR',
'taco bell': 'QSR',
'tgi friday%s': 'QSR',
'tim hortons': 'QSR',
'tropical smoothie': 'QSR',
'wendy%s': 'QSR',
'wetzel pretzel': 'QSR',
'whataburger': 'QSR',
'which wich superior sandwiches': 'QSR',
'wingstop': 'QSR',
'yogurtland': 'QSR',
'yum! brands': 'QSR',
'zaxby%s': 'QSR',
'18|8 hair salon': 'WELL',
'9 round kickboxing': 'WELL',
'9round': 'WELL',
'ac hotels': 'WELL',
'aloft': 'WELL',
'always best care senior care': 'WELL',
'amazing lash studio': 'WELL',
'american family care': 'WELL',
'regis': 'WELL',
'renaissance': 'WELL',
'residence inn': 'WELL',
'ritz-carlton': 'WELL',
'rodeway inn': 'WELL',
'roosters': 'WELL',
'senior helpers': 'WELL',
'seniors helping seniors': 'WELL',
'sheraton': 'WELL',
'sky zone sports': 'WELL',
'sleep inn': 'WELL',
'snap fitness': 'WELL',
'snip-its': 'WELL',
'sport clips': 'WELL',
'springhill suites': 'WELL',
'st. regis': 'WELL',
'starwood': 'WELL',
'starwood hotels': 'WELL',
'staybridge': 'WELL',
'staybridge suites': 'WELL',
'studio 6': 'WELL',
'suburban': 'WELL',
'suburban extended stay': 'WELL',
'super cuts': 'WELL',
'super8': 'WELL',
'sylvan learning': 'WELL',
'the goddard school': 'WELL',
'the joint': 'WELL',
'the learning experience': 'WELL',
'the little gym': 'WELL',
'the sheraton hotels & resorts': 'WELL',
'the springhill suites': 'WELL',
'title boxing club': 'WELL',
'town place suites': 'WELL',
'travelodge': 'WELL',
'tutor doctor': 'WELL',
'tutoring club': 'WELL',
'ufc gym': 'WELL',
'visiting angels': 'WELL',
'w hotels': 'WELL',
'waldorf astoria': 'WELL',
'wax center': 'WELL',
'westin': 'WELL',
'whotels': 'WELL',
'wingate': 'WELL',
'wyndham': 'WELL',
'wyndham garden': 'WELL',
'wyndham worldwide': 'WELL',
'youfit': 'WELL',
'young rembrandts': 'WELL',
    
}

#Crashes jupyter everytime ... 
#with open("usDcaDailyRun_2018_03_08.tsv") as tsv:
#    print zip(*(line.strip().split('\t') for line in tsv))
        
#This block tried to use the dicitionary for comapnies but it requireed a 100% match to the name (same problem we have now)
pDCA = pd.read_table("usDcaDailyRun_2018_03_08.tsv")
pDCA.head()
pDCA['daily_list'] = pDCA['company'].str.lower()
#d_list_tup = tuple(pDCA['daily_list'])


#pDCA['companyMatch'] = pDCA.daily_list.map.(companies)
#pDCA

#Calls in company index, sets header row, creates company_list & sets all values lower case
vertical_list = pd.read_table("brands_verticals.tsv")
vert_list_str = str(vertical_list['brand'])

#process.extract("allstate", d_list_tup, scorer=fuzz.partial_ratio)
    

def get_ratio(row):
    name = row['daily_list']
    return fuzz.token_sort_ratio(name, "jimmy jon")


for i in range(len('daily_list')):
    pDCA[pDCA.apply(get_ratio, axis=1) > 60]
    



#normtitle_list = tuple(vertical_list['daily_list'])
#test_list = re.compile('|'.join(normtitle_list))
#test_list

#def m_search(x):
#    match = re.search(normtitle_list, x)
#    if match: 
#        return match.group(0)
    
#pDCA['vertical_match'] = pDCA['company'].apply(m_search)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-3a9fa049acc3> in <module>()
#     469
#     470 for i in range(len('daily_list')):
# --> 471     pDCA[pDCA.apply(get_ratio, axis=1) > 60]
#     472
#     473
#
# /Users/bknight/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /Users/bknight/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4316                     labels = self._get_agg_axis(axis)
# ...
